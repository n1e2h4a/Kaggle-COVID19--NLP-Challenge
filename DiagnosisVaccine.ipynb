# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv

# %%
df = pd.read_csv('metadata.csv')
df.shape
# Out:
# /home/niharika/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1,4,5,6,13,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (204823, 19)

# %%
df.head()
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
# 2    Surfactant protein-D and pulmonary host defense           10.1186/rr19
# 3               Role of endothelin-1 in lung disease           10.1186/rr44
# 4  Gene expression in epithelial cells in respons...           10.1186/rr61
#
#       pmcid    pubmed_id license  \
# 0  PMC35282  1.14726e+07   no-cc
# 1  PMC59543   1.1668e+07   no-cc
# 2  PMC59549   1.1668e+07   no-cc
# 3  PMC59574  1.16869e+07   no-cc
# 4  PMC59580  1.16869e+07   no-cc
#
#                                             abstract publish_time  \
# 0  OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1  Inflammatory diseases of the respiratory tract...   2000-08-15
# 2  Surfactant protein-D (SP-D) participates in th...   2000-08-25
# 3  Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22
# 4  Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11
#
#                                              authors         journal  mag_id  \
# 0                Madani, Tariq A; Al-Ghamdi, Aisha A  BMC Infect Dis     NaN
# 1  Vliet, Albert van der; Eiserich, Jason P; Cros...      Respir Res     NaN
# 2                                    Crouch, Erika C      Respir Res     NaN
# 3  Fagan, Karen A; McMurtry, Ivan F; Rodman, David M      Respir Res     NaN
# 4  Domachowske, Joseph B; Bonville, Cynthia A; Ro...      Respir Res     NaN
#
#   who_covidence_id arxiv_id  \
# 0              NaN      NaN
# 1              NaN      NaN
# 2              NaN      NaN
# 3              NaN      NaN
# 4              NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/d1aafb70c066a2068b027...
# 1  document_parses/pdf_json/6b0567729c2143a66d737...
# 2  document_parses/pdf_json/06ced00a5fc04215949aa...
# 3  document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4  document_parses/pdf_json/5f48792a5fa08bed9f560...
#
#                                pmc_json_files  \
# 0  document_parses/pmc_json/PMC35282.xml.json
# 1  document_parses/pmc_json/PMC59543.xml.json
# 2  document_parses/pmc_json/PMC59549.xml.json
# 3  document_parses/pmc_json/PMC59574.xml.json
# 4  document_parses/pmc_json/PMC59580.xml.json
#
#                                                  url  s2_id
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    NaN
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN

# %%
df.head()
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
# 2    Surfactant protein-D and pulmonary host defense           10.1186/rr19
# 3               Role of endothelin-1 in lung disease           10.1186/rr44
# 4  Gene expression in epithelial cells in respons...           10.1186/rr61
#
#       pmcid    pubmed_id license  \
# 0  PMC35282  1.14726e+07   no-cc
# 1  PMC59543   1.1668e+07   no-cc
# 2  PMC59549   1.1668e+07   no-cc
# 3  PMC59574  1.16869e+07   no-cc
# 4  PMC59580  1.16869e+07   no-cc
#
#                                             abstract publish_time  \
# 0  OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1  Inflammatory diseases of the respiratory tract...   2000-08-15
# 2  Surfactant protein-D (SP-D) participates in th...   2000-08-25
# 3  Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22
# 4  Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11
#
#                                              authors         journal  mag_id  \
# 0                Madani, Tariq A; Al-Ghamdi, Aisha A  BMC Infect Dis     NaN
# 1  Vliet, Albert van der; Eiserich, Jason P; Cros...      Respir Res     NaN
# 2                                    Crouch, Erika C      Respir Res     NaN
# 3  Fagan, Karen A; McMurtry, Ivan F; Rodman, David M      Respir Res     NaN
# 4  Domachowske, Joseph B; Bonville, Cynthia A; Ro...      Respir Res     NaN
#
#   who_covidence_id arxiv_id  \
# 0              NaN      NaN
# 1              NaN      NaN
# 2              NaN      NaN
# 3              NaN      NaN
# 4              NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/d1aafb70c066a2068b027...
# 1  document_parses/pdf_json/6b0567729c2143a66d737...
# 2  document_parses/pdf_json/06ced00a5fc04215949aa...
# 3  document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4  document_parses/pdf_json/5f48792a5fa08bed9f560...
#
#                                pmc_json_files  \
# 0  document_parses/pmc_json/PMC35282.xml.json
# 1  document_parses/pmc_json/PMC59543.xml.json
# 2  document_parses/pmc_json/PMC59549.xml.json
# 3  document_parses/pmc_json/PMC59574.xml.json
# 4  document_parses/pmc_json/PMC59580.xml.json
#
#                                                  url  s2_id
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    NaN
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN

# %%
title = df.copy()
title = title.dropna(subset=['title'])
title['title'] = title['title'].str.replace('[^a-zA-Z]', ' ', regex=True)
title['title'] = title['title'].str.lower()
title.head()
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                title                    doi  \
# 0  clinical features of culture proven mycoplasma...  10.1186/1471-2334-1-6
# 1  nitric oxide  a pro inflammatory mediator in l...           10.1186/rr14
# 2    surfactant protein d and pulmonary host defense           10.1186/rr19
# 3               role of endothelin   in lung disease           10.1186/rr44
# 4  gene expression in epithelial cells in respons...           10.1186/rr61
#
#       pmcid    pubmed_id license  \
# 0  PMC35282  1.14726e+07   no-cc
# 1  PMC59543   1.1668e+07   no-cc
# 2  PMC59549   1.1668e+07   no-cc
# 3  PMC59574  1.16869e+07   no-cc
# 4  PMC59580  1.16869e+07   no-cc
#
#                                             abstract publish_time  \
# 0  OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1  Inflammatory diseases of the respiratory tract...   2000-08-15
# 2  Surfactant protein-D (SP-D) participates in th...   2000-08-25
# 3  Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22
# 4  Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11
#
#                                              authors         journal  mag_id  \
# 0                Madani, Tariq A; Al-Ghamdi, Aisha A  BMC Infect Dis     NaN
# 1  Vliet, Albert van der; Eiserich, Jason P; Cros...      Respir Res     NaN
# 2                                    Crouch, Erika C      Respir Res     NaN
# 3  Fagan, Karen A; McMurtry, Ivan F; Rodman, David M      Respir Res     NaN
# 4  Domachowske, Joseph B; Bonville, Cynthia A; Ro...      Respir Res     NaN
#
#   who_covidence_id arxiv_id  \
# 0              NaN      NaN
# 1              NaN      NaN
# 2              NaN      NaN
# 3              NaN      NaN
# 4              NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/d1aafb70c066a2068b027...
# 1  document_parses/pdf_json/6b0567729c2143a66d737...
# 2  document_parses/pdf_json/06ced00a5fc04215949aa...
# 3  document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4  document_parses/pdf_json/5f48792a5fa08bed9f560...
#
#                                pmc_json_files  \
# 0  document_parses/pmc_json/PMC35282.xml.json
# 1  document_parses/pmc_json/PMC59543.xml.json
# 2  document_parses/pmc_json/PMC59549.xml.json
# 3  document_parses/pmc_json/PMC59574.xml.json
# 4  document_parses/pmc_json/PMC59580.xml.json
#
#                                                  url  s2_id
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    NaN
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN

# %%
title.tail()
# Out:
#         cord_uid                                                sha  \
# 204818  tsuy82yr           d134339d956b29e179aa051605f29f003c40fafa
# 204819  kummh0g7           08c1a61166c7ff566a69185176292cdd99002c55
# 204820  hmmfmyir           2a95ce38ae354de809fba1577100199c6e39b98a
# 204821  s0djf8hz           66bc40bd3ea9bec129922138a2df0bf22d8b652a
# 204822  omeb2v9y  269baeb5806820e587fedf1703005e9938eff343; ca68...
#
#                            source_x  \
# 204818                 Medline; PMC
# 204819                 Medline; PMC
# 204820       Elsevier; Medline; PMC
# 204821  Elsevier; Medline; PMC; WHO
# 204822           Elsevier; PMC; WHO
#
#                                                     title  \
# 204818  global change of surgical and oncological clin...
# 204819  mobile health technology for enhancing the cov...
# 204820  health equity during covid     the case of ara...
# 204821  treatment of severe pneumonia due to covid    ...
# 204822  covid    waste management  effective and succe...
#
#                                     doi       pmcid    pubmed_id    license  \
# 204818       10.1007/s00345-020-03333-6  PMC7335229  3.26235e+07      cc-by
# 204819            10.4269/ajtmh.20-0506  PMC7356462  3.24766e+07      cc-by
# 204820     10.1016/j.amepre.2020.06.004  PMC7298462  3.27037e+07  els-covid
# 204821       10.1016/j.idcr.2020.e00837  PMC7242210  3.24835e+07      no-cc
# 204822  10.1016/j.resconrec.2020.105071  PMC7383137          NaN      no-cc
#
#                                                  abstract publish_time  \
# 204818  OBJECTIVES: While the coronavirus disease 2019...   2020-07-04
# 204819  Mobile Health Technology for Enhancing the COV...   2020-05-29
# 204820                                                NaN   2020-06-17
# 204821  The outbreak of the new coronavirus disease 20...   2020-05-22
# 204822  • Medical wastes will drastically increase due...   2020-07-27
#
#                                                   authors  \
# 204818  Dotzauer, Robert; Böhm, Katharina; Brandt, Max...
# 204819  Nachega, Jean B.; Leisegang, Rory; Kallay, Osc...
# 204820                                Abuelezam, Nadia N.
# 204821  El-Lababidi, Rania M.; Mooty, Mohamad; Bonilla...
# 204822  Singh, Narendra; Tang, Yuanyuan; Zhang, Zuotai...
#
#                       journal  mag_id who_covidence_id arxiv_id  \
# 204818           World J Urol     NaN              NaN      NaN
# 204819      Am J Trop Med Hyg     NaN              NaN      NaN
# 204820          Am J Prev Med     NaN              NaN      NaN
# 204821                IDCases     NaN          #327230      NaN
# 204822  Resour Conserv Recycl     NaN          #676727      NaN
#
#                                            pdf_json_files  \
# 204818  document_parses/pdf_json/d134339d956b29e179aa0...
# 204819  document_parses/pdf_json/08c1a61166c7ff566a691...
# 204820  document_parses/pdf_json/2a95ce38ae354de809fba...
# 204821  document_parses/pdf_json/66bc40bd3ea9bec129922...
# 204822  document_parses/pdf_json/269baeb5806820e587fed...
#
#                                       pmc_json_files  \
# 204818  document_parses/pmc_json/PMC7335229.xml.json
# 204819  document_parses/pmc_json/PMC7356462.xml.json
# 204820                                           NaN
# 204821  document_parses/pmc_json/PMC7242210.xml.json
# 204822  document_parses/pmc_json/PMC7383137.xml.json
#
#                                                       url        s2_id
# 204818  https://www.ncbi.nlm.nih.gov/pubmed/32623500/;...  220336893.0
# 204819  https://www.ncbi.nlm.nih.gov/pubmed/32476643/;...  219170543.0
# 204820  https://doi.org/10.1016/j.amepre.2020.06.004; ...  219709408.0
# 204821  https://www.ncbi.nlm.nih.gov/pubmed/32483527/;...  218764518.0
# 204822  https://www.sciencedirect.com/science/article/...  220772319.0

# %%
title['keyword_vaccine'] = title['title'].str.find('vaccine') 
title.head()
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                title                    doi  \
# 0  clinical features of culture proven mycoplasma...  10.1186/1471-2334-1-6
# 1  nitric oxide  a pro inflammatory mediator in l...           10.1186/rr14
# 2    surfactant protein d and pulmonary host defense           10.1186/rr19
# 3               role of endothelin   in lung disease           10.1186/rr44
# 4  gene expression in epithelial cells in respons...           10.1186/rr61
#
#       pmcid    pubmed_id license  \
# 0  PMC35282  1.14726e+07   no-cc
# 1  PMC59543   1.1668e+07   no-cc
# 2  PMC59549   1.1668e+07   no-cc
# 3  PMC59574  1.16869e+07   no-cc
# 4  PMC59580  1.16869e+07   no-cc
#
#                                             abstract publish_time  \
# 0  OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1  Inflammatory diseases of the respiratory tract...   2000-08-15
# 2  Surfactant protein-D (SP-D) participates in th...   2000-08-25
# 3  Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22
# 4  Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11
#
#                                              authors         journal  mag_id  \
# 0                Madani, Tariq A; Al-Ghamdi, Aisha A  BMC Infect Dis     NaN
# 1  Vliet, Albert van der; Eiserich, Jason P; Cros...      Respir Res     NaN
# 2                                    Crouch, Erika C      Respir Res     NaN
# 3  Fagan, Karen A; McMurtry, Ivan F; Rodman, David M      Respir Res     NaN
# 4  Domachowske, Joseph B; Bonville, Cynthia A; Ro...      Respir Res     NaN
#
#   who_covidence_id arxiv_id  \
# 0              NaN      NaN
# 1              NaN      NaN
# 2              NaN      NaN
# 3              NaN      NaN
# 4              NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/d1aafb70c066a2068b027...
# 1  document_parses/pdf_json/6b0567729c2143a66d737...
# 2  document_parses/pdf_json/06ced00a5fc04215949aa...
# 3  document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4  document_parses/pdf_json/5f48792a5fa08bed9f560...
#
#                                pmc_json_files  \
# 0  document_parses/pmc_json/PMC35282.xml.json
# 1  document_parses/pmc_json/PMC59543.xml.json
# 2  document_parses/pmc_json/PMC59549.xml.json
# 3  document_parses/pmc_json/PMC59574.xml.json
# 4  document_parses/pmc_json/PMC59580.xml.json
#
#                                                  url  s2_id  keyword_vaccine
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    NaN               -1
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN               -1
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN               -1
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN               -1
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN               -1

# %%
included_vaccine = title.loc[title['keyword_vaccine'] != -1]
included_vaccine
# Out:
#         cord_uid                                       sha  \
# 104     n9sih438  4994fa72322bbf19120592304d92629226948d8e
# 107     1n69h3i3  bada3cc0577a226694617d77f95ac443c6431969
# 121     z2u5frvq  9992ffbec7c8256d057b05a858cde82d36d64ae3
# 155     8rrkf78o  235855da90347b259f4d6b244821f3c1c264c04e
# 192     pr9i9swk  dad72c9c3422ef1c9b9149e8dd567de494d46a8a
# ...          ...                                       ...
# 204630  3ywtkd3k  deea74c59b21622d228c43adea5340e8a2447081
# 204631  rtyhmgb2  48674e3b635c0557c0d5358b8d1e6ac72c7f4e01
# 204710  wgau58zl  5b804f88f68fa6a81bf634c6740ff79253ba471a
# 204775  qek9jy2c  8283f147574b1e6ea7ce216707b66a6b3e23fc94
# 204779  h2i7tjob  cb690769762bb2fc4b4d9b898b03623b589fe8c1
#
#                       source_x  \
# 104                        PMC
# 107                        PMC
# 121                        PMC
# 155                        PMC
# 192                        PMC
# ...                        ...
# 204630            Medline; PMC
# 204631  Elsevier; Medline; PMC
# 204710      Elsevier; PMC; WHO
# 204775            Medline; PMC
# 204779            Medline; PMC
#
#                                                     title  \
# 104     rapid identification of malaria vaccine candid...
# 107     dna vaccines against protozoan parasites  adva...
# 121     antibody based hiv   vaccines  recent developm...
# 155     expression of foot and mouth disease virus cap...
# 192     nasal delivery of an adenovirus based vaccine ...
# ...                                                   ...
# 204630  systems vaccinology and big data in the vaccin...
# 204631  of viruses  vaccines  and variability  qualita...
# 204710  recent insights for the emerging covid     dru...
# 204775  evaluation of glycoprotein e subunit and live ...
# 204779  inflammasomes in antiviral immunity  clues for...
#
#                                  doi       pmcid    pubmed_id    license  \
# 104     10.1371/journal.pone.0000645  PMC1920550  1.76533e+07      cc-by
# 107               10.1155/2007/90520  PMC1940056  1.77102e+07      no-cc
# 121     10.1371/journal.pmed.0040348  PMC2100141  1.80526e+07      cc-by
# 155     10.1371/journal.pone.0002273  PMC2386233  1.85095e+07      cc-by
# 192     10.1371/journal.pone.0003548  PMC2569416  1.89582e+07      cc-by
# ...                              ...         ...          ...        ...
# 204630             10.1111/imm.13012  PMC6283655  3.03176e+07   cc-by-nc
# 204631    10.1016/j.tics.2020.05.015  PMC7266748   3.2601e+07  els-covid
# 204710    10.1016/j.ajps.2020.06.001  PMC7335243          NaN      no-cc
# 204775              10.1002/iid3.297  PMC7212201  3.21677e+07      cc-by
# 204779       10.7774/cevr.2014.3.1.5  PMC3890450  2.44278e+07   cc-by-nc
#
#                                                  abstract publish_time  \
# 104     To identify malaria antigens for vaccine devel...   2007-07-25
# 107     Over the past 15 years, DNA vaccines have gone...   2007-06-24
# 121     The authors discuss humoral immune responses t...   2007-12-01
# 155     BACKGROUND: Foot-and-mouth disease (FMD) is a ...   2008-05-28
# 192     Pre-existing immunity to human adenovirus sero...   2008-10-29
# ...                                                   ...          ...
# 204630  Systems vaccinology has proven a fascinating d...   2018-11-13
# 204631  Abstract Deaths from COVID-19 depend on millio...   2020-06-03
# 204710  SARS-CoV-2 has been marked as a highly pathoge...   2020-07-04
# 204775  INTRODUCTION: Varicella‐zoster virus (VZV), a ...   2020-03-13
# 204779  Inflammasomes are cytosolic multiprotein compl...   2013-12-18
#
#                                                   authors  \
# 104     Villard, Viviane; Agak, George W.; Frank, Géra...
# 107                                       Dumonteil, Eric
# 121     Montefiori, David; Sattentau, Quentin; Flores,...
# 155     Li, Zhiyong; Yi, Yongzhu; Yin, Xiangping; Zhan...
# 192     Croyle, Maria A.; Patel, Ami; Tran, Kaylie N.;...
# ...                                                   ...
# 204630  Raeven, René H. M.; van Riet, Elly; Meiring, H...
# 204631                                  Reyna, Valerie F.
# 204710                Zhu, Yuefei; Li, Jia; Pang, Zhiqing
# 204775  Lee, Su Jeen; Park, Hyo‐Jung; Ko, Hae Li; Lee,...
# 204779               Yamazaki, Tatsuya; Ichinohe, Takeshi
#
#                      journal  mag_id who_covidence_id arxiv_id  \
# 104                 PLoS One     NaN              NaN      NaN
# 107      J Biomed Biotechnol     NaN              NaN      NaN
# 121                 PLoS Med     NaN              NaN      NaN
# 155                 PLoS One     NaN              NaN      NaN
# 192                 PLoS One     NaN              NaN      NaN
# ...                      ...     ...              ...      ...
# 204630            Immunology     NaN              NaN      NaN
# 204631       Trends Cogn Sci     NaN              NaN      NaN
# 204710     Asian J Pharm Sci     NaN          #631901      NaN
# 204775     Immun Inflamm Dis     NaN              NaN      NaN
# 204779  Clin Exp Vaccine Res     NaN              NaN      NaN
#
#                                            pdf_json_files  \
# 104     document_parses/pdf_json/4994fa72322bbf1912059...
# 107     document_parses/pdf_json/bada3cc0577a226694617...
# 121     document_parses/pdf_json/9992ffbec7c8256d057b0...
# 155     document_parses/pdf_json/235855da90347b259f4d6...
# 192     document_parses/pdf_json/dad72c9c3422ef1c9b914...
# ...                                                   ...
# 204630  document_parses/pdf_json/deea74c59b21622d228c4...
# 204631  document_parses/pdf_json/48674e3b635c0557c0d53...
# 204710  document_parses/pdf_json/5b804f88f68fa6a81bf63...
# 204775  document_parses/pdf_json/8283f147574b1e6ea7ce2...
# 204779  document_parses/pdf_json/cb690769762bb2fc4b4d9...
#
#                                       pmc_json_files  \
# 104     document_parses/pmc_json/PMC1920550.xml.json
# 107     document_parses/pmc_json/PMC1940056.xml.json
# 121     document_parses/pmc_json/PMC2100141.xml.json
# 155     document_parses/pmc_json/PMC2386233.xml.json
# 192     document_parses/pmc_json/PMC2569416.xml.json
# ...                                              ...
# 204630  document_parses/pmc_json/PMC6283655.xml.json
# 204631                                           NaN
# 204710  document_parses/pmc_json/PMC7335243.xml.json
# 204775  document_parses/pmc_json/PMC7212201.xml.json
# 204779  document_parses/pmc_json/PMC3890450.xml.json
#
#                                                       url        s2_id  \
# 104     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...          NaN
# 107     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...          NaN
# 121     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...          NaN
# 155     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...          NaN
# 192     https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...          NaN
# ...                                                   ...          ...
# 204630  https://doi.org/10.1111/imm.13012; https://www...   52981890.0
# 204631  https://api.elsevier.com/content/article/pii/S...  219181501.0
# 204710  https://www.sciencedirect.com/science/article/...  220334627.0
# 204775  https://doi.org/10.1002/iid3.297; https://www....  212693757.0
# 204779  https://doi.org/10.7774/cevr.2014.3.1.5; https...    9243684.0
#
#         keyword_vaccine
# 104                  32
# 107                   4
# 121                  21
# 155                 134
# 192                  38
# ...                 ...
# 204630               40
# 204631               12
# 204710               83
# 204775               80
# 204779               57
#
# [3256 rows x 20 columns]

# %%
#Now that we have the filter for the articles that contain the vaccine title, we will filter the files and load them for further analysis, for this we create an array with the names of the sha that is part of the name of the json file.

shaid = []
for index, row in included_vaccine.iterrows():
    id = str(row['sha']) + ".json"
    shaid.append(id)
#now we go through the json files and we compare them with the metadata array

import json
import os
datafiles = []
for dirname, _, filenames in os.walk('pdf_json'):
    for filename in filenames:
        if not (filename==''):
            if(filename in shaid):
                ifile = os.path.join(dirname, filename)
                if ifile.split(".")[-1] == "json":
                    datafiles.append(ifile)

# %%
len(datafiles)
# Out:
# 1735

# %%
#Now we go through the selected files and create an arrangement with the body of the article.

ArrBodyText = []
for file in datafiles:
    with open(file,'r')as f:
        doc = json.load(f)
    id = doc['paper_id'] 
    bodytext = ''
    for item in doc['body_text']:
        bodytext = bodytext + item['text']
        
    ArrBodyText.append({id:bodytext})

# %%
#we check that the correct information will be loaded

ArrBodyText[20]
# Out:
# {'f13c88733ea45be9e923a282dfd42f8c277c187c': 'Acute respiratory infections (ARIs) manifest as Upper (URI) or Lower (LRI) respiratory tract infections and may move between the two compartments; ARIs represent the most common infectious diseases and are predominantly of viral aetiology. The global burden of ARI is substantial with significant morbidity and mortality occurring in children, the elderly and immunocompromised [1] .In the UK alone during the period 2014-2015, respiratory disease caused an estimated 15,800 excess winter deaths [2] . In the USA, influenza and respiratory syncytial virus (RSV) cause substantial mortality especially among people aged 65 and older [3] .However, although deaths in the industrialised world are widely reported, developing countries feel the burden particularly; out of an estimated 1.9 million child deaths from ARIs in 2000, 70% of those deaths occurred in Africa and south-east Asia [4] . The Millennium Summit at the United Nations in 2000 led to the setting up of the Millennium Development Goals.A study reported the progress made in meeting those goals in 40 developing countries; it concluded that the prevalence of ARI was 13%, health expenditure and per capita gross domestic product is directly associated with the prevalence of the disease [5] .Viral heterogeneity associated with ARIs is well established [6] . In the past, human rhinovirus (HRV) has been identified as the virus most frequently associated with respiratory illness with 30-50% of infections annually on average, and up to 80% of upper respiratory infections during the autumn outbreaks [7] . After HRVs, coronaviruses (CoV), influenza, respiratory syncytial virus (RSV) and parainfluenza viruses (PIV) are the next most frequent.More recently an evaluation of illness in 6,266 children under ten years of age in Australia, South East Asia and Latin America emphasised both the viral heterogeneity and the impact of ARI. Of the 2,421 children who experienced 3,717 individual influenza-like Illness (ILI) episodes, rhinovirus/enterovirus was most prevalent (41. 5%). Influenza followed this (15.8%), adenovirus (ADV) (9.8%), PIV and RSV (both 9.7%), CoV (5.6%), human metapneumovirus (HMPV) (5.5%) and human bocavirus (HBoV) (2.0%). The percentage of children missing school or childcare was between 21.4% for HBoV and 52.1% for influenza [8] .We have compared the data from the two reports one from 2003 [7] and the other in 2017 [8] and found that the reports, despite being separated by 14 years, were similar, with the single exception of HBoV, discovered in 2005 (Table 1) , which we discuss later.Feng et al. [9] described in detail the distribution of ARIs causing hospitalisation by age group: they observed that RSV was predominantly observed in the young and elderly, and influenza although significant in the young was noticeably more predominant in the elderly. Interestingly they observed that co-detection of viruses tended to occur more commonly in the younger age groups, particularly those under the age of five.Rhinovirus (the "common" cold) HRV infections, often considered trivial can significantly contribute to missed days from work and school, though infections are typically self-limiting [7] . HRV infections throughout the year and in many cases, manifest with symptoms such as nasal congestion, rhinorrhoea, sneezing, sore throat, and cough. HRV is known to be the primary cause of ARI and a severe contributing factor in exacerbations of atopic disease, e.g., asthma as well other conditions such as chronic obstructive pulmonary disease (COPD) [10] [11] [12] [13] .HRV infections are associated with significant economic implications as well as being an important contributor to sinusitis, otitis media, bronchitis and primary pneumonia [14] [15] [16] . HRV is a considerable cause of morbidity in specific at-risk groups such as infants, the elderly, immunocompromised, and, as already mentioned, chronic respiratory diseases such as asthma, COPD ...

# %%
#Now that we have a filter, we will start to perform other text techniques to be continue...

#Text Analysis
#We will use the NLP library called NLTK, first we will make a split on an item of the specific arrangement to be able to separate the words.

text_split = str(ArrBodyText[20]).split()
len(text_split)
# Out:
# 7491

# %%
#Identify common words
freq = pd.Series(' '.join(text_split).split()).value_counts()[:20]
freq
# Out:
# the            412
# of             297
# and            214
# in             166
# to             161
# a              111
# for             80
# is              74
# with            73
# that            66
# virus           58
# as              56
# are             48
# HVC             43
# .               42
# was             38
# studies         37
# model           37
# respiratory     35
# have            35
# dtype: int64

# %%
#Identify uncommon words
freq1 =  pd.Series(' '.join(text_split).split()).value_counts()[-20:]
freq1
# Out:
# 1990s.          1
# collective      1
# identifying     1
# Vapendavir      1
# nor             1
# rhinorrhoea,    1
# unique          1
# relatively      1
# improve         1
# exclude         1
# [70,            1
# applications    1
# 290,000         1
# diagnostics.    1
# strains.        1
# USA,            1
# [43]            1
# quick           1
# [105]           1
# St              1
# dtype: int64

# %%
#Text pre-processing can be divided into two broad categories — noise removal & normalization. Data components that are redundant to the core text analytics can be considered as noise.

from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()
stem = PorterStemmer()
word = "inversely"
print("stemming:",stem.stem(word))
print("lemmatization:", lem.lemmatize(word, "v"))
# Out:
# stemming: invers
# lemmatization: inversely

# %%
# Libraries for text preprocessing
import re
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
#nltk.download('wordnet') 
from nltk.stem.wordnet import WordNetLemmatizer

# %%
#Creating a list of stop words and adding custom stopwords and Creating a list of custom stopwords

stop_words = set(stopwords.words("english"))

new_words = ["using", "show", "result", "large", "also", "iv", "one", "two", "new", "previously", "shown","et",'al']
stop_words = stop_words.union(new_words)
corpus = []
for i in range(0, 4548):
    #Remove punctuations
    text = re.sub('[^a-zA-Z]', ' ', text_split[i])
    
    #Convert to lowercase
    text = text.lower()
    
    #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)
    
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    ##Convert to list from string
    text = text.split()
    
    ##Stemming
    ps=PorterStemmer()
    #Lemmatisation
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word) for word in text if not word in  
            stop_words] 
    text = " ".join(text)
    corpus.append(text)

# %%
#View corpus item
corpus[220]
# Out:
# 'illness'

# %%
#Data Exploration We will now visualize the text corpus that we created after pre-processing to get insights on the most frequently used words.
#Word cloud
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
#matplotlib inline
wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stop_words,
                          max_words=100,
                          max_font_size=90, 
                          random_state=62
                         ).generate(str(corpus))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=900)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f312d5c4668>
